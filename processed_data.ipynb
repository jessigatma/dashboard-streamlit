# %%
import pandas as pd
import numpy as np

# %%
datos = pd.read_csv('Tweets.csv')
datos.head()
# Out:
#              tweet_id airline_sentiment  airline_sentiment_confidence  \
# 0  570306133677760513           neutral                        1.0000
# 1  570301130888122368          positive                        0.3486
# 2  570301083672813571           neutral                        0.6837
# 3  570301031407624196          negative                        1.0000
# 4  570300817074462722          negative                        1.0000
#
#   negativereason  negativereason_confidence         airline  \
# 0            NaN                        NaN  Virgin America
# 1            NaN                     0.0000  Virgin America
# 2            NaN                        NaN  Virgin America
# 3     Bad Flight                     0.7033  Virgin America
# 4     Can't Tell                     1.0000  Virgin America
#
#   airline_sentiment_gold        name negativereason_gold  retweet_count  \
# 0                    NaN     cairdin                 NaN              0
# ...

# %%
datos['tweet_coord'][21]
# Out:
# '[40.74804263, -73.99295302]'

# %%
datos.tweet_coord.replace("[", "",inplace=True) 
#datos.tweet_coord = [col.replace("]", "") for col in datos.tweet_coord]

# %%
datos.tweet_coord.replace("]", "",inplace=True)

# %%
datos.tweet_coord
# Out:
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
#         ...
# 14635    NaN
# 14636    NaN
# 14637    NaN
# 14638    NaN
# 14639    NaN
# Name: tweet_coord, Length: 14640, dtype: object

# %%
datos['lat'], datos['long'] = datos['tweet_coord'].str.split(',', 1).str

# %%
datos['lat'].replace('[','')
datos['lat'][21]
# Out:
# '[40.74804263'

# %%
datos.tweet_coord.replace({'[':'(',']':')'},inplace=True)
datos.tweet_coord.head(25)
# Out:
# 0                             NaN
# 1                             NaN
# 2                             NaN
# 3                             NaN
# 4                             NaN
# 5                             NaN
# 6                             NaN
# 7                             NaN
# 8                             NaN
# 9                             NaN
# 10                            NaN
# 11                            NaN
# 12                            NaN
# 13                            NaN
# 14                            NaN
# 15                            NaN
# 16                            NaN
# 17                            NaN
# 18                            NaN
# 19                            NaN
# 20                            NaN
# 21    [40.74804263, -73.99295302]
# 22                            NaN
# 23                            NaN
# 24                            NaN
# Name: tweet_coord, dtype: object

# %%
datos.tweet_coord[21]
# Out:
# '[40.74804263, -73.99295302]'

# %%
datos.to_csv('Tweets_2.csv')

# %%
for coordenada in datos.lat:
    #longitud = coordenada[:len(coordenada)-1]
    print(len(coordenada))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-127-93ca4c0a273a> in <module>
#       1 for coordenada in datos.lat:
#       2     #longitud = coordenada[:len(coordenada)-1]
# ----> 3     print(len(coordenada))
#
# TypeError: object of type 'float' has no len()

# %%
datos.lat.replace("[", "",inplace=True)

# %%
datos.lat[21]
# Out:
# '[40.74804263'

# %%
for i in datos.lat:
    if i.dtype == str:
        print(i)
    else:
        print('nop')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-77-a5e7338b9021> in <module>
#       1 for i in datos.lat:
# ----> 2     if i.dtype == str:
#       3         print(i)
#       4     else:
#       5         print('nop')
#
# AttributeError: 'float' object has no attribute 'dtype'

# %%
for i in datos.lat:
    if palabra != np.NaN:
        s_palabra = palabra[1:]
    else: 
        palabra
    print(palabra)
# Out:
# n
# nan
# nan
# nan
# nan
# nan
# nan
# [36.24269903
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# [25.7789761
# [25.7789509
# nan
# nan
# nan
# [39.05365524
# nan
# nan
# nan
# nan
# nan
# nan
# [39.25956567
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# [39.87631844
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# [43.74167873
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# ...

# %%
# Create two lists for the loop results to be placed
lat = []
lon = []

# For each row in a varible,
for row in datos['tweet_coord']:
    # Try to,
    try:
        # Split the row by comma and append
        # everything before the comma to lat
        lat.append(row.split(',')[0])
        # Split the row by comma and append
        # everything after the comma to lon
        lon.append(row.split(',')[1])
    # But if you get an error
    except:
        # append a missing value to lat
        lat.append(np.NaN)
        # append a missing value to lon
        lon.append(np.NaN)

# Create two new columns from lat and lon
datos['latitude'] = lat
datos['longitude'] = lon

# %%
datos.head(50)
# Out:
# 10                      NaN                     0.0000  Virgin America
# 11                      NaN                        NaN  Virgin America
# 12                      NaN                        NaN  Virgin America
# 13                      NaN                        NaN  Virgin America
# 14                      NaN                        NaN  Virgin America
# 15              Late Flight                     0.3684  Virgin America
# 16                      NaN                        NaN  Virgin America
# 17               Bad Flight                     1.0000  Virgin America
# 18                      NaN                        NaN  Virgin America
# 19                      NaN                        NaN  Virgin America
# 20               Can't Tell                     0.3614  Virgin America
# 21                      NaN                        NaN  Virgin America
# 22                      NaN                        NaN  Virgin America
# ...

# %%
datos.to_csv('Tweets_2.csv')
